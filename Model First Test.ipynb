# %%
import pandas as pd
import numpy as np

# %%
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LogisticRegression
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
data = pd.read_csv('preprocessed including verbs.csv', sep=';')
# df = pd.read_csv("income.csv",header=None,na_values=" NaN")

# %%
data.head(2)
# Out:
#                                                title  \
# 0                                 smell hillary fear
# 1  watch exact moment paul ryan commit political ...
#
#                                                 text  label
# 0  daniel greenfield shillman journalism fellow f...    0.0
# 1  google pinterest digg linkedin reddit stumbleu...    0.0

# %%
data.columns
# Out:
# Index(['title', 'text', 'label'], dtype='object')

# %% [markdown]
# #### remove nan

# %%
data.dropna(inplace=True)

# %%
tfidf = TfidfVectorizer()

# %%
# x = tfidf.fit_transform(data["title"]).toarray()
x = tfidf.fit_transform(data["text"]).toarray()

# %%
y = data['label']

# %%
print(x.shape)
# Out:
# (6292, 49270)

# %%
print(tfidf.get_feature_names())
# Out:
# ['aa', 'aaa', 'aaahhh', 'aab', 'aachen', 'aadhar', 'aadmi', 'aae', 'aaeeb', 'aah', 'aaib', 'aaingr', 'aaj', 'aakar', 'aakhri', 'aalia', 'aaliya', 'aall', 'aaluijqn', 'aam', 'aamaq', 'aamon', 'aaojejptcy', 'aap', 'aapke', 'aapko', 'aapne', 'aarhus', 'aaron', 'aaronapollocamp', 'aarondmiller', 'aaronson', 'aarp', 'aart', 'aaso', 'aata', 'aau', 'aauw', 'aaye', 'aayush', 'aaza', 'ab', 'aba', 'abaaoud', 'ababa', 'aback', 'abad', 'abadi', 'abaldo', 'aban', 'abandon', 'abandonment', 'abandonnig', 'abate', 'abatement', 'abatzoglou', 'abay', 'abaya', 'abbakumova', 'abbar', 'abbas', 'abbe', 'abbey', 'abbn', 'abbot', 'abbott', 'abbottabad', 'abboud', 'abbreviate', 'abbreviation', 'abby', 'abc', 'abcnews', 'abcpolitics', 'abd', 'abdallah', 'abdel', 'abdelhamid', 'abdelmoumen', 'abdeslam', 'abdicate', 'abdication', 'abdikadir', 'abdirashid', 'abdiwahab', 'abdkir', 'abdollah', 'abdollahi', 'abdomen', 'abdominal', 'abdrabbuh', 'abduct', 'abductee', 'abductees', 'abduction', 'abductor', 'abdul', 'abdulazeez', 'abdulaziz', 'abdulghani', 'abdulla', 'abdullah', 'abdullahuniversity', 'abdulmohsen', 'abdulmutallab', 'abdulmuttalab', 'abdulrahman', 'abdulzai', 'abdur', 'abdurrahman', 'abdus', 'abe', 'abed', 'abedin', 'abedine', 'abedini', 'abedins', 'abednego', 'abeille', 'abel', 'abelah', 'abeldanger', 'abercrombie', 'aberfan', 'abernathy', 'abernethy', 'aberrant', 'aberration', 'aberrational', 'abeslam', 'abet', 'abetment', 'abettor', 'abha', 'abhijit', 'abhiram', 'abhor', 'abhorrent', 'abi', 'abid